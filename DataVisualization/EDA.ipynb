# %% [markdown]
# #### **Exploratory Data Analysis**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('C:\\Users\\Hp\\Desktop\\learning\\Python-Guide\\practicePandas\\thyroid2(2).csv')
df1=pd.read_csv('C:\\Users\\Hp\\Desktop\\learning\\Python-Guide\\practicePandas\\Thyroid_Diff.csv')

# %%
#df1['Physical Examination'].unique()
df.set_index('patient id',inplace=True)

# %%
# During EDA code will generate different warnings so lets disable all the warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### **Display Top 5 Rows of the Dataset**

# %%
df.head()
# Out:
#             Age  Gender  Smoking  Hx Smoking  Hx Radiothreapy  \
# patient id
# 10           27       0        0           0                0
# 12           34       0        0           1                0
# 14           30       0        0           0                0
# 16           62       0        0           0                0
# 18           62       0        0           0                0
#
#             Thyroid Function  Physical Examination  Adenopathy  Pathology  \
# patient id
# 10                         0                     0           0          0
# 12                         0                     1           0          0
# 14                         0                     2           0          0
# 16                         0                     2           0          0
# 18                         0                     1           0          0
#
#             Focality  Risk  T  N  M  Stage  Response  Recurred
# patient id
# ...

# %% [markdown]
# #### **Display Last 5 Rows of the Dataset**

# %%
df.tail()
# Out:
#             Age  Gender  Smoking  Hx Smoking  Hx Radiothreapy  \
# patient id
# 728          72       1        1           1                1
# 730          81       1        1           0                1
# 732          72       1        1           1                0
# 734          61       1        1           1                1
# 736          67       1        1           0                0
#
#             Thyroid Function  Physical Examination  Adenopathy  Pathology  \
# patient id
# 728                        0                     2           1          1
# 730                        0                     1           2          1
# 732                        0                     1           4          1
# 734                        1                     1           2          3
# 736                        0                     1           4          1
#
#             Focality  Risk  T  N  M  Stage  Response  Recurred
# patient id
# ...

# %% [markdown]
# #### **Print Rnadom 5 Rows of the dataset**

# %%
df.sample(10)
# Out:
#             Age  Gender  Smoking  Hx Smoking  Hx Radiothreapy  \
# patient id
# 102          29       0        0           0                0
# 350          30       0        0           0                0
# 462          34       0        0           0                0
# 358          44       0        0           0                0
# 574          63       0        0           0                0
# 586          31       0        0           0                0
# 194          57       0        1           0                0
# 190          31       0        0           0                0
# 580          26       0        0           0                0
# 374          25       0        0           0                0
#
#             Thyroid Function  Physical Examination  Adenopathy  Pathology  \
# patient id
# 102                        0                     1           0          2
# 350                        0                     2           0          1
# ...

# %% [markdown]
# #### **Find the number of Observation and Number of Columns in dataset**

# %%
print('Number of rows are:',df.shape[0])
print('Number of rows are:',df.shape[1])
# Out:
# Number of rows are: 364
# Number of rows are: 17

# %% [markdown]
# #### **Check for the Null Values in the dataset**

# %%
df.isnull().sum()
# Out:
# Age                     0
# Gender                  0
# Smoking                 0
# Hx Smoking              0
# Hx Radiothreapy         0
# Thyroid Function        0
# Physical Examination    0
# Adenopathy              0
# Pathology               0
# Focality                0
# Risk                    0
# T                       0
# N                       0
# M                       0
# Stage                   0
# Response                0
# Recurred                0
# dtype: int64

# %% [markdown]
# #### **Get Information about dataset like total number of observations/columns, datatypes of each column & memory requirement**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 364 entries, 10 to 736
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Age                   364 non-null    int64
#  1   Gender                364 non-null    int64
#  2   Smoking               364 non-null    int64
#  3   Hx Smoking            364 non-null    int64
#  4   Hx Radiothreapy       364 non-null    int64
#  5   Thyroid Function      364 non-null    int64
#  6   Physical Examination  364 non-null    int64
#  7   Adenopathy            364 non-null    int64
#  8   Pathology             364 non-null    int64
#  9   Focality              364 non-null    int64
#  10  Risk                  364 non-null    int64
#  11  T                     364 non-null    int64
#  12  N                     364 non-null    int64
#  13  M                     364 non-null    int64
#  14  Stage                 364 non-null    int64
# ...

# %% [markdown]
# #### **Get overall Statistics about the dataset**

# %%
df.describe()
#in following 25%,50%,75% are percentiles such as in Age column
# 25% values are below 30 
# 50% values are below 38
# 75% values are below 52
# max value is 82
# Out:
#              Age      Gender     Smoking  Hx Smoking  Hx Radiothreapy  \
# count  364.00000  364.000000  364.000000  364.000000       364.000000
# mean    41.25000    0.195055    0.134615    0.076923         0.019231
# std     15.31436    0.396788    0.341782    0.266836         0.137524
# min     15.00000    0.000000    0.000000    0.000000         0.000000
# 25%     30.00000    0.000000    0.000000    0.000000         0.000000
# 50%     38.00000    0.000000    0.000000    0.000000         0.000000
# 75%     52.00000    0.000000    0.000000    0.000000         0.000000
# max     82.00000    1.000000    1.000000    1.000000         1.000000
#
#        Thyroid Function  Physical Examination  Adenopathy   Pathology  \
# count        364.000000            364.000000  364.000000  364.000000
# mean           0.315934              1.203297    0.689560    1.063187
# std            0.910102              0.895283    1.304707    0.646130
# ...

# %% [markdown]
# ### **Univariate Analysis**
# #### 1:**

# %%
#---------------------------------------------------------- Understanding Eaxh Column --------------------------------------------------------------------
