# %%
import pandas as pd
df=pd.read_csv('all_data.csv')
df
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 1           NaN                         NaN              NaN        NaN
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %%
df [['Date', 'Time']]=df['Order Date'].str.split('', n=1,expand=True)
df
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 1           NaN                         NaN              NaN        NaN
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address Date  \
# ...

# %%
df[['month', 'Days','year']]=df['Date'].str.split('/',n=3, expand=True)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df[['month', 'Days','year']]=df['Date'].str.split('/',n=3, expand=True)
#       2 df
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py:4299, in DataFrame.__setitem__(self, key, value)
#    4297     self._setitem_frame(key, value)
#    4298 elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 4299     self._setitem_array(key, value)
#    4300 elif isinstance(value, DataFrame):
#    4301     self._set_item_frame_value(key, value)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py:4341, in DataFrame._setitem_array(self, key, value)
#    4336 else:
#    4337     # Note: unlike self.iloc[:, indexer] = value, this will
#    4338     #  never try to overwrite values inplace
#    4340     if isinstance(value, DataFrame):
# ...

# %%
#print(df)
#droping the NAN values
df.dropna (inplace=True)
#print(df)
df.reset_index(drop=True) #<----reset the index

#split into two coloums data and time
#print(df)

#print(df)
#split the Date colums into month, Days and year
df[['month', 'Days','year']]=df['Date'].str.split('/',n=2, expand=True)
print(df)
#delete the 'Date' column
del df['Date']

print(df)
#check the type of month column
df ['month'].dtype #<---object type
#obj into numneric
df['month']=pd.to_numeric(df['month'], errors='coerce')
#selling
print(df.groupby('month').month.sum().nlargest(5))

#--or-
print(df.groupby('month').month.sum().sort_values (ascending=False))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 12
#       5 df.reset_index(drop=True) #<----reset the index
#       7 #split into two coloums data and time
#       8 #print(df)
#       9
#      10 #print(df)
#      11 #split the Date colums into month, Days and year
# ---> 12 df[['month', 'Days','year']]=df['Date'].str.split('/',n=2, expand=True)
#      13 print(df)
#      14 #delete the 'Date' column
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py:4299, in DataFrame.__setitem__(self, key, value)
#    4297     self._setitem_frame(key, value)
#    4298 elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 4299     self._setitem_array(key, value)
#    4300 elif isinstance(value, DataFrame):
#    4301     self._set_item_frame_value(key, value)
#
# ...

# %%
import pandas as pd

df = pd.read_csv('all_data.csv')

# Drop rows with NaN values
df.dropna(inplace=True)

# Reset the index
df.reset_index(drop=True, inplace=True)

# Split 'Order Date' into 'Date' and 'Time'
df[['Date', 'Time']] = df['Order Date'].str.split(' ', n=1, expand=True)

# Split the 'Date' column into 'month', 'Days', and 'year'
df[['month', 'Days', 'year']] = df['Date'].str.split('/', n=2, expand=True)

# Delete the 'Date' column
del df['Date']

# Convert 'month' column to numeric, coercing errors to NaN
df['month'] = pd.to_numeric(df['month'], errors='coerce')

# Group by 'month' and sum the 'Quantity Ordered' column, showing the top 5
#print(df.groupby('month')['Quantity Ordered'].sum().nlargest(5))

# Alternatively, sort all month sums in descending order
print(df.groupby('month')['Quantity Ordered'].sum().sort_values(ascending=False))
# Out:
# month
# 8.0     2112211111111111111111111111121111131211112111...
# 4.0     2111111111111111111111111112111211111112131121...
# 11.0    1211111111111111111311111121111111111111211111...
# 1.0     1121411111111111111111111111311112112111111111...
# 10.0    1121111111111111111111111111111111111111121131...
# 7.0     1111511111111111211111112112112111111111111121...
# 2.0     1111211111111111111211111112411121111211111111...
# 12.0    1111111214212211111111411111112111111211121111...
# 5.0     1111111111211111111111111111111121111111111111...
# 9.0     1111111111114211111111131111111111111121111111...
# 3.0     1111111111111111211211111151211111111131111111...
# 6.0     1111111111111111111111131111111211111211111111...
# Name: Quantity Ordered, dtype: object
